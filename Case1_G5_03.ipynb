# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Scotland_Expenditure.xlsx', sheet_name = 'Scotland', header = 7)

df = df[df['Description'] == 'Food and drink']
df = df.drop([6,11], axis=0)
df.drop(df.columns[2:5], axis=1, inplace=True)
df = df.drop(['RSE indicator(a)', '% change since 201819', 'sig(b)', 'trend since 20819(c)'], axis = 1).reset_index(drop=True)
df.drop(df.columns[0], axis=1, inplace=True)
# Out:
#       Description Units      2001-02      2002-03      2003-04      2004-05  \
# 0  Food and drink     p  3218.519926  3305.171933  3256.012375  3322.466204
#
#        2005-06         2006         2007         2008  ...         2013  \
# 0  3547.380058  3634.619126  3760.339014  3860.106535  ...  4318.110179
#
#           2014         2015       201516       201617       201718  \
# 0  4341.605085  4226.461069  4293.871566  4535.415129  4370.995202
#
#         201819       201920      202021       202122
# 0  4453.737588  4213.707807  3701.13947  4372.693495
#
# [1 rows x 24 columns]

# %%
plt.figure(figsize=(10, 10))

plt.plot(df.columns[2:].astype(str), df.iloc[0, 2:], marker = 'o', linestyle = '-')

plt.ylabel('Expenditure (pence/week)')
plt.xlabel('Years')
plt.title(f'Expenditure on Food and Drinks (Scotland)', fontsize = 15)
plt.grid(True)
plt.xticks(rotation = 90)
plt.show()
